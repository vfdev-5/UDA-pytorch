# %% [markdown]
# # CIFAR10 dataflow

# %%
import sys

sys.path.insert(0, "../code")

# %%
from utils import get_train_test_loaders

# %%
train_labelled_loader, train_unlabelled_loader, test_loader = \
    get_train_test_loaders(dataset_name="CIFAR10", 
                           num_labelled_samples=4000,
                           path="../input/cifar10",
                           batch_size=16,
                           unlabelled_batch_size=32,
                           num_workers=12)
# Out:
# Files already downloaded and verified

# %%
len(train_labelled_loader), len(train_unlabelled_loader)
# Out:
# (250, 1438)

# %%
train_unlabelled_loader_iter = iter(train_unlabelled_loader)
train_labelled_loader_iter = iter(train_labelled_loader)

# %%
unlabelled_x, unlabelled_aug_x = next(train_unlabelled_loader_iter)
labelled_x, y = next(train_labelled_loader_iter)

# %%
labelled_x.shape, y.shape, unlabelled_x.shape, unlabelled_aug_x.shape
# Out:
# (torch.Size([16, 3, 32, 32]),
#  torch.Size([16]),
#  torch.Size([32, 3, 32, 32]),
#  torch.Size([32, 3, 32, 32]))

# %%
from torchvision.utils import make_grid
from torchvision.transforms import functional as f

# %%
res = make_grid(labelled_x, normalize=True)

f.to_pil_image(res)
# Out:
# <PIL.Image.Image image mode=RGB size=274x70 at 0x7FA26832A2B0>

# %%
res = make_grid(unlabelled_x, normalize=True)

f.to_pil_image(res)
# Out:
# <PIL.Image.Image image mode=RGB size=274x138 at 0x7FA2602C0B70>

# %%
res = make_grid(unlabelled_aug_x, normalize=True)

f.to_pil_image(res)
# Out:
# <PIL.Image.Image image mode=RGB size=274x138 at 0x7FA2602CE7F0>
